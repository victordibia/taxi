# %% [markdown]
# <a href="https://colab.research.google.com/github/victordibia/taxi/blob/main/notebooks/data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Download Data
#
# - Ingest sample data from NY Taxi Data

# %%
# !mkdir data
# !mkdir data/zones
# !wget -O data/january.csv https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-01.csv
# !wget -O data/june.csv https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-06.csv
# !wget -O data/zoneshape.zip https://s3.amazonaws.com/nyc-tlc/misc/taxi_zones.zip 
# !wget -O data/zonelookup.zip https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# !unzip data/zoneshape.zip -d data/zones
# Out:
# --2020-12-16 05:03:30--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-01.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.88.149
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.88.149|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 593610736 (566M) [text/csv]
# Saving to: ‘data/january.csv’
#
# data/january.csv    100%[===================>] 566.11M  97.6MB/s    in 5.9s
#
# 2020-12-16 05:03:36 (95.9 MB/s) - ‘data/january.csv’ saved [593610736/593610736]
#
# --2020-12-16 05:03:36--  https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2020-06.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.37.134
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.37.134|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50277193 (48M) [text/csv]
# Saving to: ‘data/june.csv’
#
# data/june.csv       100%[===================>]  47.95M   112MB/s    in 0.4s
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
jan_df = pd.read_csv("data/january.csv")
jan_df
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          VendorID tpep_pickup_datetime  ... total_amount  congestion_surcharge
# 0             1.0  2020-01-01 00:28:15  ...        11.27                   2.5
# 1             1.0  2020-01-01 00:35:39  ...        12.30                   2.5
# 2             1.0  2020-01-01 00:47:41  ...        10.80                   2.5
# 3             1.0  2020-01-01 00:55:23  ...         8.16                   0.0
# 4             2.0  2020-01-01 00:01:58  ...         4.80                   0.0
# ...           ...                  ...  ...          ...                   ...
# 6405003       NaN  2020-01-31 22:51:00  ...        21.14                   0.0
# 6405004       NaN  2020-01-31 22:10:00  ...        62.46                   0.0
# ...
